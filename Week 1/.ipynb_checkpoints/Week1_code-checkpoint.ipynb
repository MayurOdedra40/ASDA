# %% [raw]
# Prgoram to Create a Dictonary

# %%
import string

# Created a string
inputString = "One of the main issues that degrowth in general is concerned with inequality and its reduction (Hickel, 2021).Hence, distribution and the question of redistribution of wealth, income and resources have continued to resurface in the degrowth literature of (Cosme et al., 2017; Martinez- Alier, 2009; Spangenberg, 2010; Xue et al., 2012). Not so prominently discussed within degrowth, but not less relavent, is the question of money and its role for economic growth itself monetary system  as such indeed fueled the need for economic growth,i.e. if a monetary growth imperative existed, as some For economic growth, if a monetary growth imperative exists, as some economists argue (e.g., Binswanger, 2013), there is a pressing need for analyses and proposals on how to design a monetary system that aligns better with the degrowth agenda. Given the immediate relevance of the monetary growth imperative to degrowth, one would expect that degrowth scholarship would prominently address the issue of money. The same applies to the development of concrete policies regarding district issues or monetary system design. However, there is a notable lack in this area. Of concrete policy proposals from  the regrowth literature has been lamented Repeatedly over the years in different contexts (Berg and Hukkinen, 2011; Bonaiutl, 2018; Demaria et al., 2013; Joutsenvirta, 2016; van den Bergh, 2011), and previous Reviews of the degrowth literature have confirmed this on a general level to some extent (Cosme et al, 2017; Fitzpatrick et al., 2022; Sekutova et al., 2013; Vlderia et al., 2014). In particular, a wide variety of different kinds of goals, objectives and in struments proposed in degree with has been attested, as weak as a commonplace lack of precision in proposals (Fizpatrick el al., 2022, p. 8). One possible explanation for this lack can be found in the relation- ship between degrowth and the state. Given the undertheorized role of the state as a central player in the degrowth transition (Demaria et al., 2019; D’Alisa and Kallis, 2020) degrowth faces a tension between viewing the state as incapable of initiating transformational change and making a political appeal to it to do precisely this viatargeted eco-social policies leaving a lack in research on the strategic implications arising from conceptualizationsof the state and state-civil society relations within degrowth/postgrowth approaches (Koch, 2020 p. 1). clusters based on similarities in conceptual vocabulary."
cleanedString = ""
removedCharacters = []

# List of special characters to be removed
specialCharacters = ['!', '@', '#', '$', '%', '^', '&', '*', '(', ')', '-', '_', '=', '+', '{', '}', '[', ']', ':', ';', '"', "'", '<', '>', ',', '.', '?', '/', '\\', '|', '`', '~']

#seprate special Characters from string
for char in inputString:
        if char in specialCharacters:
            removedCharacters.append(char)  # Mark down the removed special character
        else:
            cleanedString += char

# %%
# Split the string by spaces
words = cleanedString.split()

#create a list of alphabets
lowercaseAlphabets = list(string.ascii_lowercase)
# Create a dictionary to count each word
wordCount = {}
characterCount = {}

for word in words:
    wordLower = word.lower()  
    wordCount[wordLower] = wordCount.get(wordLower, 0) + 1 

for word in removedCharacters:
    characterCount[word] = characterCount.get(word, 0) + 1

# %%
# Initialize an empty list to store dictionaries
wordList = []
existing_values = set()

for word in words:
    wordLower = word.lower()
    if wordLower not in existing_values:
    # Create a dictionary for each word
        newWord = {
            'word': word,
            'length': len(word),
            'lowercase': wordLower,
            'OnlyWord': (word in lowercaseAlphabets), 
            'count': wordCount[wordLower],
            'isSpecialCharacter': (1 == 2)
        }
        # add the dictionary to the list
        wordList.append(newWord)
        existing_values.add(wordLower)
        
#add special Characters
for word in removedCharacters:
    if word not in existing_values:
    # Create a dictionary for each word
        newWord = {
            'word': word,
            'length': len(word),
            'lowercase': word,
            'OnlyWord': (word in lowercaseAlphabets), 
            'count': characterCount[word],
            'isSpecialCharacter': (1 == 1)
        }
        # add the dictionary to the list
        wordList.append(newWord)
        existing_values.add(word)

# %%
# Display the results
for info in wordList:
    print(info)
# Out:
# {'word': 'One', 'length': 3, 'lowercase': 'one', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'of', 'length': 2, 'lowercase': 'of', 'OnlyWord': False, 'count': 15, 'isSpecialCharacter': False}
# {'word': 'the', 'length': 3, 'lowercase': 'the', 'OnlyWord': False, 'count': 22, 'isSpecialCharacter': False}
# {'word': 'main', 'length': 4, 'lowercase': 'main', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'issues', 'length': 6, 'lowercase': 'issues', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'that', 'length': 4, 'lowercase': 'that', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'degrowth', 'length': 8, 'lowercase': 'degrowth', 'OnlyWord': False, 'count': 10, 'isSpecialCharacter': False}
# {'word': 'in', 'length': 2, 'lowercase': 'in', 'OnlyWord': False, 'count': 12, 'isSpecialCharacter': False}
# {'word': 'general', 'length': 7, 'lowercase': 'general', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'is', 'length': 2, 'lowercase': 'is', 'OnlyWord': False, 'count': 4, 'isSpecialCharacter': False}
# {'word': 'concerned', 'length': 9, 'lowercase': 'concerned', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'with', 'length': 4, 'lowercase': 'with', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'inequality', 'length': 10, 'lowercase': 'inequality', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'and', 'length': 3, 'lowercase': 'and', 'OnlyWord': False, 'count': 12, 'isSpecialCharacter': False}
# {'word': 'its', 'length': 3, 'lowercase': 'its', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'reduction', 'length': 9, 'lowercase': 'reduction', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Hickel', 'length': 6, 'lowercase': 'hickel', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2021Hence', 'length': 9, 'lowercase': '2021hence', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'distribution', 'length': 12, 'lowercase': 'distribution', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'question', 'length': 8, 'lowercase': 'question', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'redistribution', 'length': 14, 'lowercase': 'redistribution', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'wealth', 'length': 6, 'lowercase': 'wealth', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'income', 'length': 6, 'lowercase': 'income', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'resources', 'length': 9, 'lowercase': 'resources', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'have', 'length': 4, 'lowercase': 'have', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'continued', 'length': 9, 'lowercase': 'continued', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'to', 'length': 2, 'lowercase': 'to', 'OnlyWord': False, 'count': 7, 'isSpecialCharacter': False}
# {'word': 'resurface', 'length': 9, 'lowercase': 'resurface', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'literature', 'length': 10, 'lowercase': 'literature', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'Cosme', 'length': 5, 'lowercase': 'cosme', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'et', 'length': 2, 'lowercase': 'et', 'OnlyWord': False, 'count': 8, 'isSpecialCharacter': False}
# {'word': 'al', 'length': 2, 'lowercase': 'al', 'OnlyWord': False, 'count': 9, 'isSpecialCharacter': False}
# {'word': '2017', 'length': 4, 'lowercase': '2017', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'Martinez', 'length': 8, 'lowercase': 'martinez', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Alier', 'length': 5, 'lowercase': 'alier', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2009', 'length': 4, 'lowercase': '2009', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Spangenberg', 'length': 11, 'lowercase': 'spangenberg', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2010', 'length': 4, 'lowercase': '2010', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Xue', 'length': 3, 'lowercase': 'xue', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2012', 'length': 4, 'lowercase': '2012', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Not', 'length': 3, 'lowercase': 'not', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'so', 'length': 2, 'lowercase': 'so', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'prominently', 'length': 11, 'lowercase': 'prominently', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'discussed', 'length': 9, 'lowercase': 'discussed', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'within', 'length': 6, 'lowercase': 'within', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'but', 'length': 3, 'lowercase': 'but', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'less', 'length': 4, 'lowercase': 'less', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'relavent', 'length': 8, 'lowercase': 'relavent', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'money', 'length': 5, 'lowercase': 'money', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'role', 'length': 4, 'lowercase': 'role', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'for', 'length': 3, 'lowercase': 'for', 'OnlyWord': False, 'count': 5, 'isSpecialCharacter': False}
# {'word': 'economic', 'length': 8, 'lowercase': 'economic', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'growth', 'length': 6, 'lowercase': 'growth', 'OnlyWord': False, 'count': 5, 'isSpecialCharacter': False}
# {'word': 'itself', 'length': 6, 'lowercase': 'itself', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'monetary', 'length': 8, 'lowercase': 'monetary', 'OnlyWord': False, 'count': 6, 'isSpecialCharacter': False}
# {'word': 'system', 'length': 6, 'lowercase': 'system', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'as', 'length': 2, 'lowercase': 'as', 'OnlyWord': False, 'count': 7, 'isSpecialCharacter': False}
# {'word': 'such', 'length': 4, 'lowercase': 'such', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'indeed', 'length': 6, 'lowercase': 'indeed', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'fueled', 'length': 6, 'lowercase': 'fueled', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'need', 'length': 4, 'lowercase': 'need', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'growthie', 'length': 8, 'lowercase': 'growthie', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'if', 'length': 2, 'lowercase': 'if', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'a', 'length': 1, 'lowercase': 'a', 'OnlyWord': True, 'count': 12, 'isSpecialCharacter': False}
# {'word': 'imperative', 'length': 10, 'lowercase': 'imperative', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'existed', 'length': 7, 'lowercase': 'existed', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'some', 'length': 4, 'lowercase': 'some', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'exists', 'length': 6, 'lowercase': 'exists', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'economists', 'length': 10, 'lowercase': 'economists', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'argue', 'length': 5, 'lowercase': 'argue', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'eg', 'length': 2, 'lowercase': 'eg', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Binswanger', 'length': 10, 'lowercase': 'binswanger', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2013', 'length': 4, 'lowercase': '2013', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'there', 'length': 5, 'lowercase': 'there', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'pressing', 'length': 8, 'lowercase': 'pressing', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'analyses', 'length': 8, 'lowercase': 'analyses', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'proposals', 'length': 9, 'lowercase': 'proposals', 'OnlyWord': False, 'count': 3, 'isSpecialCharacter': False}
# {'word': 'on', 'length': 2, 'lowercase': 'on', 'OnlyWord': False, 'count': 4, 'isSpecialCharacter': False}
# {'word': 'how', 'length': 3, 'lowercase': 'how', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'design', 'length': 6, 'lowercase': 'design', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'aligns', 'length': 6, 'lowercase': 'aligns', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'better', 'length': 6, 'lowercase': 'better', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'agenda', 'length': 6, 'lowercase': 'agenda', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Given', 'length': 5, 'lowercase': 'given', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'immediate', 'length': 9, 'lowercase': 'immediate', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'relevance', 'length': 9, 'lowercase': 'relevance', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'would', 'length': 5, 'lowercase': 'would', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'expect', 'length': 6, 'lowercase': 'expect', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'scholarship', 'length': 11, 'lowercase': 'scholarship', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'address', 'length': 7, 'lowercase': 'address', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'issue', 'length': 5, 'lowercase': 'issue', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'same', 'length': 4, 'lowercase': 'same', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'applies', 'length': 7, 'lowercase': 'applies', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'development', 'length': 11, 'lowercase': 'development', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'concrete', 'length': 8, 'lowercase': 'concrete', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'policies', 'length': 8, 'lowercase': 'policies', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'regarding', 'length': 9, 'lowercase': 'regarding', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'district', 'length': 8, 'lowercase': 'district', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'or', 'length': 2, 'lowercase': 'or', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'However', 'length': 7, 'lowercase': 'however', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'notable', 'length': 7, 'lowercase': 'notable', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'lack', 'length': 4, 'lowercase': 'lack', 'OnlyWord': False, 'count': 4, 'isSpecialCharacter': False}
# {'word': 'this', 'length': 4, 'lowercase': 'this', 'OnlyWord': False, 'count': 4, 'isSpecialCharacter': False}
# {'word': 'area', 'length': 4, 'lowercase': 'area', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'policy', 'length': 6, 'lowercase': 'policy', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'from', 'length': 4, 'lowercase': 'from', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'regrowth', 'length': 8, 'lowercase': 'regrowth', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'has', 'length': 3, 'lowercase': 'has', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'been', 'length': 4, 'lowercase': 'been', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'lamented', 'length': 8, 'lowercase': 'lamented', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Repeatedly', 'length': 10, 'lowercase': 'repeatedly', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'over', 'length': 4, 'lowercase': 'over', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'years', 'length': 5, 'lowercase': 'years', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'different', 'length': 9, 'lowercase': 'different', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'contexts', 'length': 8, 'lowercase': 'contexts', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Berg', 'length': 4, 'lowercase': 'berg', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Hukkinen', 'length': 8, 'lowercase': 'hukkinen', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2011', 'length': 4, 'lowercase': '2011', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'Bonaiutl', 'length': 8, 'lowercase': 'bonaiutl', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2018', 'length': 4, 'lowercase': '2018', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Demaria', 'length': 7, 'lowercase': 'demaria', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'Joutsenvirta', 'length': 12, 'lowercase': 'joutsenvirta', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2016', 'length': 4, 'lowercase': '2016', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'van', 'length': 3, 'lowercase': 'van', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'den', 'length': 3, 'lowercase': 'den', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Bergh', 'length': 5, 'lowercase': 'bergh', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'previous', 'length': 8, 'lowercase': 'previous', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Reviews', 'length': 7, 'lowercase': 'reviews', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'confirmed', 'length': 9, 'lowercase': 'confirmed', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'level', 'length': 5, 'lowercase': 'level', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'extent', 'length': 6, 'lowercase': 'extent', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Fitzpatrick', 'length': 11, 'lowercase': 'fitzpatrick', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2022', 'length': 4, 'lowercase': '2022', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'Sekutova', 'length': 8, 'lowercase': 'sekutova', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Vlderia', 'length': 7, 'lowercase': 'vlderia', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2014', 'length': 4, 'lowercase': '2014', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'particular', 'length': 10, 'lowercase': 'particular', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'wide', 'length': 4, 'lowercase': 'wide', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'variety', 'length': 7, 'lowercase': 'variety', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'kinds', 'length': 5, 'lowercase': 'kinds', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'goals', 'length': 5, 'lowercase': 'goals', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'objectives', 'length': 10, 'lowercase': 'objectives', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'struments', 'length': 9, 'lowercase': 'struments', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'proposed', 'length': 8, 'lowercase': 'proposed', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'degree', 'length': 6, 'lowercase': 'degree', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'attested', 'length': 8, 'lowercase': 'attested', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'weak', 'length': 4, 'lowercase': 'weak', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'commonplace', 'length': 11, 'lowercase': 'commonplace', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'precision', 'length': 9, 'lowercase': 'precision', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Fizpatrick', 'length': 10, 'lowercase': 'fizpatrick', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'el', 'length': 2, 'lowercase': 'el', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'p', 'length': 1, 'lowercase': 'p', 'OnlyWord': True, 'count': 2, 'isSpecialCharacter': False}
# {'word': '8', 'length': 1, 'lowercase': '8', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'possible', 'length': 8, 'lowercase': 'possible', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'explanation', 'length': 11, 'lowercase': 'explanation', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'can', 'length': 3, 'lowercase': 'can', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'be', 'length': 2, 'lowercase': 'be', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'found', 'length': 5, 'lowercase': 'found', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'relation', 'length': 8, 'lowercase': 'relation', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'ship', 'length': 4, 'lowercase': 'ship', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'between', 'length': 7, 'lowercase': 'between', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'state', 'length': 5, 'lowercase': 'state', 'OnlyWord': False, 'count': 4, 'isSpecialCharacter': False}
# {'word': 'undertheorized', 'length': 14, 'lowercase': 'undertheorized', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'central', 'length': 7, 'lowercase': 'central', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'player', 'length': 6, 'lowercase': 'player', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'transition', 'length': 10, 'lowercase': 'transition', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2019', 'length': 4, 'lowercase': '2019', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'D’Alisa', 'length': 7, 'lowercase': 'd’alisa', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Kallis', 'length': 6, 'lowercase': 'kallis', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '2020', 'length': 4, 'lowercase': '2020', 'OnlyWord': False, 'count': 2, 'isSpecialCharacter': False}
# {'word': 'faces', 'length': 5, 'lowercase': 'faces', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'tension', 'length': 7, 'lowercase': 'tension', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'viewing', 'length': 7, 'lowercase': 'viewing', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'incapable', 'length': 9, 'lowercase': 'incapable', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'initiating', 'length': 10, 'lowercase': 'initiating', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'transformational', 'length': 16, 'lowercase': 'transformational', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'change', 'length': 6, 'lowercase': 'change', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'making', 'length': 6, 'lowercase': 'making', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'political', 'length': 9, 'lowercase': 'political', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'appeal', 'length': 6, 'lowercase': 'appeal', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'it', 'length': 2, 'lowercase': 'it', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'do', 'length': 2, 'lowercase': 'do', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'precisely', 'length': 9, 'lowercase': 'precisely', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'viatargeted', 'length': 11, 'lowercase': 'viatargeted', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'ecosocial', 'length': 9, 'lowercase': 'ecosocial', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'leaving', 'length': 7, 'lowercase': 'leaving', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'research', 'length': 8, 'lowercase': 'research', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'strategic', 'length': 9, 'lowercase': 'strategic', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'implications', 'length': 12, 'lowercase': 'implications', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'arising', 'length': 7, 'lowercase': 'arising', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'conceptualizationsof', 'length': 20, 'lowercase': 'conceptualizationsof', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'statecivil', 'length': 10, 'lowercase': 'statecivil', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'society', 'length': 7, 'lowercase': 'society', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'relations', 'length': 9, 'lowercase': 'relations', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'degrowthpostgrowth', 'length': 18, 'lowercase': 'degrowthpostgrowth', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'approaches', 'length': 10, 'lowercase': 'approaches', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'Koch', 'length': 4, 'lowercase': 'koch', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '1', 'length': 1, 'lowercase': '1', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'clusters', 'length': 8, 'lowercase': 'clusters', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'based', 'length': 5, 'lowercase': 'based', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'similarities', 'length': 12, 'lowercase': 'similarities', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'conceptual', 'length': 10, 'lowercase': 'conceptual', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': 'vocabulary', 'length': 10, 'lowercase': 'vocabulary', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': False}
# {'word': '(', 'length': 1, 'lowercase': '(', 'OnlyWord': False, 'count': 8, 'isSpecialCharacter': True}
# {'word': ',', 'length': 1, 'lowercase': ',', 'OnlyWord': False, 'count': 36, 'isSpecialCharacter': True}
# {'word': ')', 'length': 1, 'lowercase': ')', 'OnlyWord': False, 'count': 8, 'isSpecialCharacter': True}
# {'word': '.', 'length': 1, 'lowercase': '.', 'OnlyWord': False, 'count': 25, 'isSpecialCharacter': True}
# {'word': ';', 'length': 1, 'lowercase': ';', 'OnlyWord': False, 'count': 11, 'isSpecialCharacter': True}
# {'word': '-', 'length': 1, 'lowercase': '-', 'OnlyWord': False, 'count': 4, 'isSpecialCharacter': True}
# {'word': '/', 'length': 1, 'lowercase': '/', 'OnlyWord': False, 'count': 1, 'isSpecialCharacter': True}
